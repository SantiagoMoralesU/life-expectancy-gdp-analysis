# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels

df = pd.read_csv("all_data.csv")
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB
#               Year  Life expectancy at birth (years)           GDP
# count    96.000000                         96.000000  9.600000e+01
# mean   2007.500000                         72.789583  3.880499e+12
# std       4.633971                         10.672882  5.197561e+12
# min    2000.000000                         44.300000  4.415703e+09
# 25%    2003.750000                         74.475000  1.733018e+11
# ...

# %%
print(df.Country.nunique())
# Out:
# 6

# %%
print(df['Country'].unique())
print(df['Year'].min(), df['Year'].max())
print(df.columns.tolist())
# Out:
# ['Chile' 'China' 'Germany' 'Mexico' 'United States of America' 'Zimbabwe']
# 2000 2015
# ['Country', 'Year', 'Life expectancy at birth (years)', 'GDP']

# %%
df = df.rename(columns={
    "Life expectancy at birth (years)": "Lifex"
})

# %%
sns.scatterplot(x="Life expectancy at birth (years)", y="GDP", data=df, hue = "Country")
# Out:
# <AxesSubplot:xlabel='Life expectancy at birth (years)', ylabel='GDP'>

# %%
sns.scatterplot(x="Life expectancy at birth (years)", y="Year", data=df, hue = "Country")
# Out:
# <AxesSubplot:xlabel='Life expectancy at birth (years)', ylabel='Year'>

# %%
sns.relplot(x="Life expectancy at birth (years)",y="GDP",data = df, col = "Country", col_wrap=3, facet_kws={"sharey": False, "sharex": False},)
